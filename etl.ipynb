# %% [markdown]
# # ETL Processes
# Use this notebook to develop the ETL process for each of your tables before completing the `etl.py` file to load the whole datasets.

# %%
import os
import glob
import psycopg2
import pandas as pd
from sql_queries import *

# %%
import datetime

# %%
conn = psycopg2.connect("host=127.0.0.1 dbname=sparkifydb user=student password=student")
cur = conn.cursor()

# %%
def get_files(filepath):
    all_files = []
    for root, dirs, files in os.walk(filepath):
        files = glob.glob(os.path.join(root,'*.json'))
        for f in files :
            all_files.append(os.path.abspath(f))
    
    return all_files

# %% [markdown]
# # Process `song_data`
# In this first part, you'll perform ETL on the first dataset, `song_data`, to create the `songs` and `artists` dimensional tables.
#
# Let's perform ETL on a single song file and load a single record into each table to start.
# - Use the `get_files` function provided above to get a list of all song JSON files in `data/song_data`
# - Select the first song in this list
# - Read the song file and view the data

# %%
filepath = "data/song_data/"

# %%
song_files = get_files(filepath)

# %%
df = pd.read_json(song_files[0], lines=True)
df.head()
# Out:
#             artist_id  artist_latitude artist_location  artist_longitude  \
# 0  ARD0S291187B9B7BF5              NaN            Ohio               NaN
#
#   artist_name   duration  num_songs             song_id  \
# 0     Rated R  114.78159          1  SOMJBYD12A6D4F8557
#
#                    title  year
# 0  Keepin It Real (Skit)     0

# %% [markdown]
# ## #1: `songs` Table
# #### Extract Data for Songs Table
# - Select columns for song ID, title, artist ID, year, and duration
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `song_data`

# %%
# df.filter(['song_id', 'title', 'artist_id', 'year', 'duration']).values.tolist()

# %%
song_data = df.filter(['song_id', 'title', 'artist_id', 'year', 'duration']).values.tolist()[0]
song_data
# Out:
# ['SOMJBYD12A6D4F8557',
#  'Keepin It Real (Skit)',
#  'ARD0S291187B9B7BF5',
#  0,
#  114.78159]

# %% [markdown]
# #### Insert Record into Song Table
# Implement the `song_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song into the `songs` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songs` table in the sparkify database.

# %%
# cur.execute?

# %%
cur.execute(song_table_insert, song_data)
conn.commit()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-23-0c375ac7939b> in <module>()
# ----> 1 cur.execute(song_table_insert, song_data)
#       2 conn.commit()
#
# IntegrityError: duplicate key value violates unique constraint "songs_pkey"
# DETAIL:  Key (song_id)=(SOMJBYD12A6D4F8557) already exists.

# %%
# cur.execute("INSERT INTO songs (song_id, title, artist_id, year, duration) VALUES(%s, %s, %s, %s, %s);", song_data)
# conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# ## #2: `artists` Table
# #### Extract Data for Artists Table
# - Select columns for artist ID, name, location, latitude, and longitude
# - Use `df.values` to select just the values from the dataframe
# - Index to select the first (only) record in the dataframe
# - Convert the array to a list and set it to `artist_data`

# %%
# df.filter(['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']).values.tolist()

# %%
artist_data = df.filter(['artist_id', 'artist_name', 'artist_location', 'artist_latitude', 'artist_longitude']).values.tolist()[0]
artist_data
# Out:
# ['ARD0S291187B9B7BF5', 'Rated R', 'Ohio', nan, nan]

# %% [markdown]
# #### Insert Record into Artist Table
# Implement the `artist_table_insert` query in `sql_queries.py` and run the cell below to insert a record for this song's artist into the `artists` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `artists` table in the sparkify database.

# %%
cur.execute(artist_table_insert, artist_data)
conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added a record to this table.

# %% [markdown]
# # Process `log_data`
# In this part, you'll perform ETL on the second dataset, `log_data`, to create the `time` and `users` dimensional tables, as well as the `songplays` fact table.
#
# Let's perform ETL on a single log file and load a single record into each table.
# - Use the `get_files` function provided above to get a list of all log JSON files in `data/log_data`
# - Select the first log file in this list
# - Read the log file and view the data

# %%
filepath = "./data/log_data/"

# %%
log_files = get_files(filepath)

# %%
df = pd.read_json(log_files[0], lines=True)
df.head()
# Out:
#                 artist       auth firstName gender  itemInSession lastName  \
# 0  Dee Dee Bridgewater  Logged In      Lily      F             38     Koch
# 1          Tim O'brien  Logged In      Lily      F             39     Koch
# 2              Nirvana  Logged In      Lily      F             40     Koch
# 3               Weezer  Logged In      Lily      F             41     Koch
# 4            Nightwish  Logged In      Lily      F             42     Koch
#
#       length level                            location method      page  \
# 0  318.64118  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong
# 1  176.14322  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong
# 2  215.11791  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong
# 3  479.32036  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong
# 4  286.19710  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong
#
#    registration  sessionId                    song  status             ts  \
# 0  1.541048e+12        818          La Vie En Rose     200  1542845032796
# 1  1.541048e+12        818  Think About Last Night     200  1542845350796
# 2  1.541048e+12        818               Love Buzz     200  1542845526796
# 3  1.541048e+12        818          Only In Dreams     200  1542845741796
# 4  1.541048e+12        818           She Is My Sin     200  1542846220796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 1  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 2  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 3  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15

# %%
df.columns
# Out:
# Index(['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName',
#        'length', 'level', 'location', 'method', 'page', 'registration',
#        'sessionId', 'song', 'status', 'ts', 'userAgent', 'userId'],
#       dtype='object')

# %% [markdown]
# ## #3: `time` Table
# #### Extract Data for Time Table
# - Filter records by `NextSong` action
# - Convert the `ts` timestamp column to datetime
#   - Hint: the current timestamp is in milliseconds
# - Extract the timestamp, hour, day, week of year, month, year, and weekday from the `ts` column and set `time_data` to a list containing these values in order
#   - Hint: use pandas' [`dt` attribute](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.html) to access easily datetimelike properties.
# - Specify labels for these columns and set to `column_labels`
# - Create a dataframe, `time_df,` containing the time data for this file by combining `column_labels` and `time_data` into a dictionary and converting this into a dataframe

# %%
df = df.loc[df['page']=='NextSong']
df.head()
# Out:
#                 artist       auth firstName gender  itemInSession lastName  \
# 0  Dee Dee Bridgewater  Logged In      Lily      F             38     Koch
# 1          Tim O'brien  Logged In      Lily      F             39     Koch
# 2              Nirvana  Logged In      Lily      F             40     Koch
# 3               Weezer  Logged In      Lily      F             41     Koch
# 4            Nightwish  Logged In      Lily      F             42     Koch
#
#       length level                            location method      page  \
# 0  318.64118  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong
# 1  176.14322  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong
# 2  215.11791  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong
# 3  479.32036  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong
# 4  286.19710  paid  Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong
#
#    registration  sessionId                    song  status             ts  \
# 0  1.541048e+12        818          La Vie En Rose     200  1542845032796
# 1  1.541048e+12        818  Think About Last Night     200  1542845350796
# 2  1.541048e+12        818               Love Buzz     200  1542845526796
# 3  1.541048e+12        818          Only In Dreams     200  1542845741796
# 4  1.541048e+12        818           She Is My Sin     200  1542846220796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 1  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 2  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 3  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15
# 4  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     15

# %%
t = df['ts']=pd.to_datetime(df['ts'], unit = 'ms')
t.head()
# Out:
# 0   2018-11-22 00:03:52.796
# 1   2018-11-22 00:09:10.796
# 2   2018-11-22 00:12:06.796
# 3   2018-11-22 00:15:41.796
# 4   2018-11-22 00:23:40.796
# Name: ts, dtype: datetime64[ns]

# %%
# Out:
# <bound method DataFrame.duplicated of                                             artist       auth firstName  \
# 0                              Dee Dee Bridgewater  Logged In      Lily
# 1                                      Tim O'brien  Logged In      Lily
# 2                                          Nirvana  Logged In      Lily
# 3                                           Weezer  Logged In      Lily
# 4                                        Nightwish  Logged In      Lily
# 5                         California Swag District  Logged In      Lily
# 6                                       Miike Snow  Logged In      Lily
# 7                                       Katy Perry  Logged In      Lily
# 8                                            Sikth  Logged In      Lily
# 9                                       Lily Allen  Logged In      Lily
# 10  The Presidents of the United States of America  Logged In      Lily
# 11                                      Wordsworth  Logged In      Lily
# 12                                         Rihanna  Logged In      Lily
# 13                                     Tomas Bodin  Logged In      Lily
# 14                                 Black Eyed Peas  Logged In      Lily
# 15                                   Carolina Liar  Logged In      Lily
# 16                                          Kansas  Logged In      Lily
# 17                                            Onar  Logged In      Lily
# 18                                            Live  Logged In      Lily
# 19                                   Abstract Rude  Logged In      Lily
# 20                                   Johnny Horton  Logged In      Lily
# 21                      The Men They Couldn't Hang  Logged In      Lily
# 22                                      Rilo Kiley  Logged In      Lily
# 23                                         Shwayze  Logged In      Lily
# 24                                  Bram Vermeulen  Logged In      Lily
# 25                             Death Cab for Cutie  Logged In      Lily
# 26                                   Dwight Yoakam  Logged In      Lily
# 27           Jadakiss / Ghostface Killah / Raekwon  Logged In      Lily
# 28                                          Rosana  Logged In      Lily
# 32                                     The Killers  Logged In      Lily
# ..                                             ...        ...       ...
# 58                                        Coldplay  Logged In      Kate
# 59                                          Atreyu  Logged In      Kate
# 60                               Bruce Springsteen  Logged In      Kate
# 61                                        BjÃÂ¶rk  Logged In      Kate
# 62                                        Big Shug  Logged In      Kate
# 63                                 The Wallflowers  Logged In      Kate
# 64                                     Chris Brown  Logged In      Kate
# 65                                Charly GarcÃÂ­a  Logged In      Kate
# 66                                N.W.A ft. Eazy-E  Logged In      Kate
# 67                     The Mighty Mighty Bosstones  Logged In      Kate
# 68                                    Beastie Boys  Logged In      Kate
# 69                                          Yuksek  Logged In      Kate
# 70                                Fernando Ubiergo  Logged In      Kate
# 71                                         Phoenix  Logged In      Kate
# 72                                   Radney Foster  Logged In    Jayden
# 73                                    Neneh Cherry  Logged In    Jayden
# 74                                       Hooligans  Logged In      Ayla
# 75                       Kid Cudi / MGMT / Ratatat  Logged In      Lily
# 76                                           Foals  Logged In    Morris
# 77                            'N Sync/Phil Collins  Logged In    Morris
# 78                               Kristian Stanfill  Logged In    Jayden
# 79                                Enrique Iglesias  Logged In    Jayden
# 80                                   Michael Cretu  Logged In    Jayden
# 81                                  Tommy Emmanuel  Logged In    Jayden
# 87                                         Cherise  Logged In   Stefany
# 89                                   Anna Waronker  Logged In    Jayden
# 90                                  King ChangÃÂ³  Logged In   Cecilia
# 91                                    Gang Of Four  Logged In   Cecilia
# 92                                     Line Renaud  Logged In   Cecilia
# 95                            the bird and the bee  Logged In     Tegan
#
#    gender  itemInSession lastName     length level  \
# 0       F             38     Koch  318.64118  paid
# 1       F             39     Koch  176.14322  paid
# 2       F             40     Koch  215.11791  paid
# 3       F             41     Koch  479.32036  paid
# 4       F             42     Koch  286.19710  paid
# 5       F             43     Koch  239.17669  paid
# 6       F             44     Koch  385.35791  paid
# 7       F             45     Koch  179.40853  paid
# 8       F             46     Koch  250.53995  paid
# 9       F             47     Koch  199.88853  paid
# 10      F             48     Koch  495.77751  paid
# 11      F             49     Koch  253.15220  paid
# 12      F             50     Koch  229.04118  paid
# 13      F             51     Koch  396.53832  paid
# 14      F             52     Koch  326.86975  paid
# 15      F             53     Koch  240.45669  paid
# 16      F             54     Koch  202.29179  paid
# 17      F             55     Koch  306.67710  paid
# 18      F             56     Koch  286.98077  paid
# 19      F             57     Koch  196.85832  paid
# 20      F             58     Koch  131.81342  paid
# 21      F             59     Koch  251.14077  paid
# 22      F             60     Koch  234.03057  paid
# 23      F             61     Koch  201.63873  paid
# 24      F             62     Koch  251.42812  paid
# 25      F             63     Koch  189.38730  paid
# 26      F             64     Koch  239.30730  paid
# 27      F             65     Koch  173.76608  paid
# 28      F             66     Koch  256.31302  paid
# 32      F             67     Koch  230.39955  paid
# ..    ...            ...      ...        ...   ...
# 58      F             15  Harrell  139.12771  paid
# 59      F             16  Harrell  308.37506  paid
# 60      F             17  Harrell  270.54975  paid
# 61      F             18  Harrell  348.57751  paid
# 62      F             19  Harrell  140.56444  paid
# 63      F             20  Harrell  315.24526  paid
# 64      F             21  Harrell  203.80689  paid
# 65      F             22  Harrell  231.73179  paid
# 66      F             23  Harrell  338.18077  paid
# 67      F             24  Harrell  158.87628  paid
# 68      F             25  Harrell  211.72200  paid
# 69      F             26  Harrell  218.95791  paid
# 70      F             27  Harrell  218.74893  paid
# 71      F             28  Harrell  192.86159  paid
# 72      M              0      Fox  288.96608  free
# 73      M              1      Fox  232.20200  free
# 74      F              0  Johnson  189.98812  free
# 75      F              0    Burns  295.67955  free
# 76      M              0  Gilmore  316.89098  free
# 77      M              1  Gilmore  143.64689  free
# 78      M              0      Fox  287.50322  free
# 79      M              1      Fox  241.42322  free
# 80      M              2      Fox  301.06077  free
# 81      M              3      Fox  168.14975  free
# 87      F              0    White  229.69424  free
# 89      F              0    Duffy  189.62240  free
# 90      F              0    Owens  340.74077  free
# 91      F              1    Owens  193.14893  free
# 92      F              2    Owens  176.16934  free
# 95      F              2   Levine  198.11220  paid
#
#                                  location method      page  registration  \
# 0      Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 1      Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 2      Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 3      Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 4      Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 5      Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 6      Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 7      Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 8      Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 9      Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 10     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 11     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 12     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 13     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 14     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 15     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 16     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 17     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 18     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 19     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 20     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 21     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 22     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 23     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 24     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 25     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 26     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 27     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 28     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# 32     Chicago-Naperville-Elgin, IL-IN-WI    PUT  NextSong  1.541048e+12
# ..                                    ...    ...       ...           ...
# 58               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 59               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 60               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 61               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 62               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 63               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 64               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 65               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 66               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 67               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 68               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 69               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 70               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 71               Lansing-East Lansing, MI    PUT  NextSong  1.540473e+12
# 72               New Orleans-Metairie, LA    PUT  NextSong  1.541034e+12
# 73               New Orleans-Metairie, LA    PUT  NextSong  1.541034e+12
# 74                         Santa Rosa, CA    PUT  NextSong  1.540880e+12
# 75  New York-Newark-Jersey City, NY-NJ-PA    PUT  NextSong  1.540621e+12
# 76                            Raleigh, NC    PUT  NextSong  1.540972e+12
# 77                            Raleigh, NC    PUT  NextSong  1.540972e+12
# 78               New Orleans-Metairie, LA    PUT  NextSong  1.541034e+12
# 79               New Orleans-Metairie, LA    PUT  NextSong  1.541034e+12
# 80               New Orleans-Metairie, LA    PUT  NextSong  1.541034e+12
# 81               New Orleans-Metairie, LA    PUT  NextSong  1.541034e+12
# 87                            Lubbock, TX    PUT  NextSong  1.540708e+12
# 89            Seattle-Tacoma-Bellevue, WA    PUT  NextSong  1.540146e+12
# 90      Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong  1.541032e+12
# 91      Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong  1.541032e+12
# 92      Atlanta-Sandy Springs-Roswell, GA    PUT  NextSong  1.541032e+12
# 95            Portland-South Portland, ME    PUT  NextSong  1.540794e+12
#
#     sessionId                                               song  status  \
# 0         818                                     La Vie En Rose     200
# 1         818                             Think About Last Night     200
# 2         818                                          Love Buzz     200
# 3         818                                     Only In Dreams     200
# 4         818                                      She Is My Sin     200
# 5         818                             Teach Me How To Dougie     200
# 6         818                                             Silvia     200
# 7         818                                    I Kissed A Girl     200
# 8         818                                          Peep Show     200
# 9         818                                           Not Fair     200
# 10        818                                               Lump     200
# 11        818                  Right Now (Produced by Ayatollah)     200
# 12        818                                         Take A Bow     200
# 13        818                         Back To The African Garden     200
# 14        818                                           My Humps     200
# 15        818       Show Me What I'm Looking For (Album Version)     200
# 16        818                                   Dust in The Wind     200
# 17        818                                  Xehasmeni Melodia     200
# 18        818                                     Lakini's Juice     200
# 19        818                                          Nuff Fire     200
# 20        818                             Mean Mean Son Of A Gun     200
# 21        818                                        Ironmasters     200
# 22        818                 The Absence Of God (Album Version)     200
# 23        818                                       Lost My Mind     200
# 24        818                                              Mamma     200
# 25        818    I Will Follow You into the Dark (Album Version)     200
# 26        818                                     You're The One     200
# 27        818                                   Cartel Gathering     200
# 28        818                                     Si tu no estas     200
# 32        818                    The Ballad of Michael Valentine     200
# ..        ...                                                ...     ...
# 58        828                                        Don't Panic     200
# 59        828  You Were The King_ Now You're Unconscious (Alb...     200
# 60        828                                        Born To Run     200
# 61        828                                               Undo     200
# 62        828                                 It Just Don't Stop     200
# 63        828                                   Be Your Own Girl     200
# 64        828                   Ain't No Way (You Won't Love Me)     200
# 65        828                 Filosofia Barata Y Zapatos De Goma     200
# 66        828                                    Boyz-N-The-Hood     200
# 67        828                                              1-2-8     200
# 68        828                      Unite (2009 Digital Remaster)     200
# 69        828                                        Take A Ride     200
# 70        828                               Cuando Agosto Era 21     200
# 71        828                                      Napoleon Says     200
# 72        790                                     Sweet And Wild     200
# 73        790                                           Manchild     200
# 74        785                                          Szex & KV     200
# 75        786                   Pursuit Of Happiness (nightmare)     200
# 76        351                                         Blue Blood     200
# 77        351       Trashin' The Camp (Phil And 'N Sync Version)     200
# 78        838                                         I Need You     200
# 79        838                               Tired Of Being Sorry     200
# 80        838                                  The Invisible Man     200
# 81        838                                       Windy & Warm     200
# 87        772                                      No Good 4 You     200
# 89        662                                   Nothing Personal     200
# 90        763                                       ConfesiÃÂ³n     200
# 91        763                          I Found That Essence Rare     200
# 92        763                                            Le Soir     200
# 95        823                               Last Day Of Our Love     200
#
#                         ts                                          userAgent  \
# 0  2018-11-22 00:03:52.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 1  2018-11-22 00:09:10.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 2  2018-11-22 00:12:06.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 3  2018-11-22 00:15:41.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 4  2018-11-22 00:23:40.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 5  2018-11-22 00:28:26.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 6  2018-11-22 00:32:25.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 7  2018-11-22 00:38:50.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 8  2018-11-22 00:41:49.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 9  2018-11-22 00:45:59.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 10 2018-11-22 00:49:18.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 11 2018-11-22 00:57:33.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 12 2018-11-22 01:01:46.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 13 2018-11-22 01:05:35.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 14 2018-11-22 01:12:11.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 15 2018-11-22 01:17:37.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 16 2018-11-22 01:21:37.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 17 2018-11-22 01:24:59.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 18 2018-11-22 01:30:05.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 19 2018-11-22 01:34:51.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 20 2018-11-22 01:38:07.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 21 2018-11-22 01:40:18.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 22 2018-11-22 01:44:29.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 23 2018-11-22 01:48:23.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 24 2018-11-22 01:51:44.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 25 2018-11-22 01:55:55.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 26 2018-11-22 01:59:04.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 27 2018-11-22 02:03:03.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 28 2018-11-22 02:05:56.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 32 2018-11-22 02:10:12.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# ..                     ...                                                ...
# 58 2018-11-22 11:52:14.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 59 2018-11-22 11:54:33.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 60 2018-11-22 11:59:41.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 61 2018-11-22 12:04:11.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 62 2018-11-22 12:09:59.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 63 2018-11-22 12:12:19.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 64 2018-11-22 12:17:34.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 65 2018-11-22 12:20:57.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 66 2018-11-22 12:24:48.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 67 2018-11-22 12:30:26.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 68 2018-11-22 12:33:04.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 69 2018-11-22 12:36:35.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 70 2018-11-22 12:40:13.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 71 2018-11-22 12:43:51.796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 72 2018-11-22 13:16:32.796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 73 2018-11-22 13:21:20.796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 74 2018-11-22 13:21:21.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 75 2018-11-22 14:04:15.796  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 76 2018-11-22 14:58:47.796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_1 like...
# 77 2018-11-22 15:04:03.796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_1 like...
# 78 2018-11-22 15:05:08.796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 79 2018-11-22 15:09:55.796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 80 2018-11-22 15:13:56.796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 81 2018-11-22 15:18:57.796  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...
# 87 2018-11-22 17:18:20.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 89 2018-11-22 18:11:07.796  "Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like...
# 90 2018-11-22 20:18:25.796  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...
# 91 2018-11-22 20:24:05.796  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...
# 92 2018-11-22 20:27:18.796  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:32.0) G...
# 95 2018-11-22 22:11:34.796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#    userId
# 0      15
# 1      15
# 2      15
# 3      15
# 4      15
# 5      15
# 6      15
# 7      15
# 8      15
# 9      15
# 10     15
# 11     15
# 12     15
# 13     15
# 14     15
# 15     15
# 16     15
# 17     15
# 18     15
# 19     15
# 20     15
# 21     15
# 22     15
# 23     15
# 24     15
# 25     15
# 26     15
# 27     15
# 28     15
# 32     15
# ..    ...
# 58     97
# 59     97
# 60     97
# 61     97
# 62     97
# 63     97
# 64     97
# 65     97
# 66     97
# 67     97
# 68     97
# 69     97
# 70     97
# 71     97
# 72    101
# 73    101
# 74     63
# 75     32
# 76     23
# 77     23
# 78    101
# 79    101
# 80    101
# 81    101
# 87     83
# 89     76
# 90      6
# 91      6
# 92      6
# 95     80
#
# [82 rows x 18 columns]>

# %%
#   hour, day, week of year, month, year, and weekday 
# start_time, hour, day, week, month, year, weekday

# %%
# time_data = {'start_time': t.dt.time,
#             'hour': t.dt.hour, 
#             'day': t.dt.day, 
#             'week': t.dt.weekofyear, 
#              'month': t.dt.month,
#              'year': t.dt.year,
#              'weekday': t.dt.weekday}
# time_data

# %%
time_data = [t.dt.time, t.dt.hour, t.dt.day, t.dt.weekofyear, t.dt.month, t.dt.year, t.dt.weekday]
column_labels = ('start_time', 'hour', 'day', 'week', 'month', 'year', 'weekday')

# %%
time_df = pd.DataFrame(time_data, index=column_labels)
# time_df.columns = column_labels
time_df.T.head()
# Out:
#         start_time hour day week month  year weekday
# 0  00:03:52.796000    0  22   47    11  2018       3
# 1  00:09:10.796000    0  22   47    11  2018       3
# 2  00:12:06.796000    0  22   47    11  2018       3
# 3  00:15:41.796000    0  22   47    11  2018       3
# 4  00:23:40.796000    0  22   47    11  2018       3

# %% [markdown]
# #### Insert Records into Time Table
# Implement the `time_table_insert` query in `sql_queries.py` and run the cell below to insert records for the timestamps in this log file into the `time` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `time` table in the sparkify database.

# %%
for i, row in time_df.iterrows():
    cur.execute(time_table_insert, list(row))
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #4: `users` Table
# #### Extract Data for Users Table
# - Select columns for user ID, first name, last name, gender and level and set to `user_df`

# %%
user_df = df.filter(items=['userId', 'firstName', 'lastName', 'gender', 'level'], axis = 1)
user_df.head()
# Out:
#   userId firstName lastName gender level
# 0     15      Lily     Koch      F  paid
# 1     15      Lily     Koch      F  paid
# 2     15      Lily     Koch      F  paid
# 3     15      Lily     Koch      F  paid
# 4     15      Lily     Koch      F  paid

# %% [markdown]
# #### Insert Records into Users Table
# Implement the `user_table_insert` query in `sql_queries.py` and run the cell below to insert records for the users in this log file into the `users` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `users` table in the sparkify database.

# %%
for i, row in user_df.iterrows():
    cur.execute(user_table_insert, row)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# ## #5: `songplays` Table
# #### Extract Data and Songplays Table
# This one is a little more complicated since information from the songs table, artists table, and original log file are all needed for the `songplays` table. Since the log file does not specify an ID for either the song or the artist, you'll need to get the song ID and artist ID by querying the songs and artists tables to find matches based on song title, artist name, and song duration time.
# - Implement the `song_select` query in `sql_queries.py` to find the song ID and artist ID based on the title, artist name, and duration of a song.
# - Select the timestamp, user ID, level, song ID, artist ID, session ID, location, and user agent and set to `songplay_data`
#
# #### Insert Records into Songplays Table
# - Implement the `songplay_table_insert` query and run the cell below to insert records for the songplay actions in this log file into the `songplays` table. Remember to run `create_tables.py` before running the cell below to ensure you've created/resetted the `songplays` table in the sparkify database.

# %%
df.columns
# Out:
# Index(['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName',
#        'length', 'level', 'location', 'method', 'page', 'registration',
#        'sessionId', 'song', 'status', 'ts', 'userAgent', 'userId'],
#       dtype='object')

# %%
# songplay_id, start_time, user_id, level, song_id, artist_id, session_id, location, user_agent

# %%
for index, row in df.iterrows():

    # get songid and artistid from song and artist tables
    cur.execute(song_select, (row.song, row.artist, row.length))
    results = cur.fetchone()
    
    if results:
        songid, artistid = results
    else:
        songid, artistid = None, None

    # insert songplay record
    songplay_data=(index, row.ts, row.userId, row.level, songid, artistid, row.sessionId, row.location, row.userAgent)
    cur.execute(songplay_table_insert, songplay_data)
    conn.commit()

# %% [markdown]
# Run `test.ipynb` to see if you've successfully added records to this table.

# %% [markdown]
# # Close Connection to Sparkify Database

# %%
conn.close()

# %% [markdown]
# # Implement `etl.py`
# Use what you've completed in this notebook to implement `etl.py`.
